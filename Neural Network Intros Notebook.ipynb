# %% [markdown]
# ## Introdução a Redes Neurais - Tests Notebook

# %% [markdown]
# ![hq-new-plot-perceptron-combine.png](attachment:hq-new-plot-perceptron-combine.png)

# %% [markdown]
# ![perceptron-formula.gif](attachment:perceptron-formula.gif)

# %% [markdown]
# Quais são os pesos e vieses para o perceptron do E?
# Defina os pesos (peso1, peso2) e o viés vies com os valores corretos de modo que eles calculem a operação E como mostrada abaixo.
# Neste caso, existem dois inputs como vistos na tabela acima (chamaremos a primeira coluna deinput1 e a segunda de input2) e levando em conta a fórmula do perceptron, podemos calcular o output.
#
# Primeiro, a combinação linear será a soma dos inputs multiplicados pelo peso: combinacao_linear = peso1*input1 + peso2*input2 então podemos colocar esse valor dentro da função de Heaviside junto com o viés, que nos retornará o output (0 ou 1):

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 1.0
weight2 = 1.0
bias = -1


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, True, True, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# Nice!  You got it all correct.
#
# Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#       0          0                  -1.0                    0          Yes
#       0          1                   0.0                    1          Yes
#       1          0                   0.0                    1          Yes
#       1          1                   1.0                    1          Yes

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 0.0
weight2 = -1.0
bias = 0.0


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [True, False, True, False]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# Nice!  You got it all correct.
#
# Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#       0          0                   0.0                    1          Yes
#       0          1                  -1.0                    0          Yes
#       1          0                   0.0                    1          Yes
#       1          1                  -1.0                    0          Yes
